# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from scipy import stats
from collections import defaultdict
import shap
import datetime
import pickle
from sklearn.model_selection import StratifiedKFold

from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE

from sklearn import svm
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from math import inf

# %%
brand = 'Fendi'
df = pd.read_pickle('../data/%s_refined.pkl' %brand)

# %%
max_date = max(df['sc_date'])- datetime.timedelta(days=30)

# %% [markdown]
# ## Labeling

# %%
df = df[-df['lifetime'].isnull()] # remove if lifetime can't be  recognized
df = df[df.apply(lambda x: x['sc_date'] == x['sc_date_first_date'], axis = 1)]

# %%
def labelling_model_1(row):
    if row['lifetime'] <= 30 and row['status'] == 'Complete' and row['ever_sold'] == 1:
        return 1.0
    elif row['lifetime'] > 30:
        return 0.0
    else:
        return None

# %%
df['label'] = df.apply(lambda x: labelling_model_1(x), axis = 1)
df_copy_test = pd.DataFrame(data=df)

# %%
count_df = df[df['sc_date_first_date'] < max_date]

# %%
count_df['label'].value_counts()
# Out:
# 0.0    17
# 1.0    13
# Name: label, dtype: int64

# %%
df = df[-df['label'].isnull()]
df_copy_train = pd.DataFrame(data=df)

# %%
df.columns
# Out:
# Index(['bags_brand', 'id', 'sc_date', 'bags_color', 'bags_condition',
#        'materials_list', 'bags_price_refined', 'sold_price_refined',
#        'retail_price_refined', 'likes', 'size', 'search_tradesy_fendi',
#        'search_fendi', 'search_fendi_kan_i', 'sc_date_last_date',
#        'sc_date_first_date', 'ever_sold', 'lifetime', 'status',
#        'number_similar', 'avg_similar', 'original_to_avg', 'price_to_retail',
#        'price_percentile', 'label'],
#       dtype='object')

# %%
if len(set(df['size'])) > 1: 
    remove_cols = {'bags_brand', 'id', 'sc_date', 'sold_price_refined', 'likes', 'sc_date_first_date',
                                    'sc_date_last_date', 'lifetime', 'status', 'price_percentile', 'label', 'ever_sold'}
    ordinal_cols = ['bags_condition']
    categorical_cols = ['bags_color', 'materials_list', 'size']
else:
    remove_cols =  {'bags_brand', 'id', 'sc_date', 'sold_price_refined', 'likes', 'sc_date_first_date',
                                    'sc_date_last_date', 'lifetime', 'status', 'price_percentile', 'label', 'size', 'ever_sold'}
    ordinal_cols = ['bags_condition']
    categorical_cols = ['bags_color', 'materials_list']

# %%
def loo(feature_value, label_value, feature_dict):
    if len(feature_dict[feature_value]) == 1 or feature_value is None:
        return (sum(feature_dict['all']) - label_value) / (len(feature_dict['all']) - 1)
    else:
        return (sum(feature_dict[feature_value]) - label_value) / (len(feature_dict[feature_value]) - 1)

# %%
def LOO_encoder(train_df, test_df, categorical_cols, label_col):
    for feature in categorical_cols:
        feature_dict = defaultdict(list)
        for i, row in train_df.iterrows():
            feature_dict[row[feature]].append(row[label_col])
            feature_dict['all'].append(row[label_col])
        train_df['%s_loo'%feature] = train_df.apply(lambda x: loo(x[feature], x[label_col], feature_dict), axis = 1)
        test_df['%s_loo'%feature] = test_df.apply(lambda x: loo(x[feature], x[label_col], feature_dict), axis = 1)
    return train_df, test_df

# %%
def OH_encoder(train_df, test_df, ordinal_cols):
    for feature in ordinal_cols:
        feature_states = list(set(train_df[feature]).union(set(test_df[feature])))[:-1]
        for state in feature_states:
            train_df['%s_%s'%(feature,state)] = train_df[feature].map(lambda x: int(x == state))
            test_df['%s_%s'%(feature,state)] = test_df[feature].map(lambda x: int(x == state))
    return train_df, test_df

# %%
def refine_cols(cols):
    if brand == 'Chanel':
        for column in ['avg_similar', 'price_to_retail']:
            cols.remove(column)
    elif brand == 'Louis Vuitton':
        for column in ['avg_similar', 'price_to_retail']:
            cols.remove(column)
    elif brand == 'Gucci':
        for column in ['avg_similar']:
            cols.remove(column)
    elif brand == 'Saint Laurent':
        for column in []:
            cols.remove(column)
    elif brand == 'Fendi':
        for column in ['avg_similar']:
            cols.remove(column)
    return cols

# %%
models_quality = {'svm':{'t1': 0, 'f0': 0, 'f1': 0, 't0': 0},
                 'lr':{'t1': 0, 'f0': 0, 'f1': 0, 't0': 0},
                 'xgb':{'t1': 0, 'f0': 0, 'f1': 0, 't0': 0},
                 'ensemble':{'t1': 0, 'f0': 0, 'f1': 0, 't0': 0}}

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
skf.get_n_splits(df)
# Out:
# 5

# %%
import itertools as it

def pop_element(d: dict, el):
    d1 = d.copy()
    del d1[el]
    return d1

def grid_iterator(combinations, param_names):
    for c in combinations:
        output_dict = {}
        for key, value in zip (param_names, c):
            output_dict[key] = value
        yield output_dict

def grid_search_params(*params):
    if len(params[0]) == 1 and type(list(params[0].values())[0]) == list:
        param_names = [list(d.keys())[0] for d in params]
        combinations = [p for p in it.product(*[list(dictionary.values())[0] for dictionary in params])]
        return grid_iterator(combinations, param_names)
    else:
        d = params[0]
        for param_name in d.keys():
            if type(d[param_name]) == list:
                list_of_args = [pop_element(d, param_name), {param_name: d[param_name]}]
                for arg in params[1:]:
                    list_of_args.append(arg)
                return grid_search_params(*list_of_args)
            elif type(d[param_name]) == dict:
                for param_value in d[param_name].keys():
                    list_of_args = [d[param_name][param_value], {param_name: [param_value]}]
                    for arg in params[1:]:
                        list_of_args.append(arg)
                    return grid_search_params(*list_of_args)

# %%
svm_params = {
    'C': [0.01, 0.1, 1, 10, 100],
    'kernel': {
        'rbf': {
            'gamma': [0.01, 0.1, 1, 10, 100]
        },
    'poly': {
        'degree': [1, 2, 3, 4]}
    }
}

lr_params = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': {'l2': {
        'solver': ['newton-cg', 'lbfgs', 'sag', 'saga']
                      },
                'l1': {
        'solver': ['liblinear', 'saga']
                },
                'elasticnet': {
        'solver': ['saga'], 'l1_ratio': [0.1, 0.5, 0.9]
                }
            }
}

xgb_params = {
    "learning_rate"    : [0.1, 0.2, 0.30] ,
    "max_depth"        : [4, 6, 8],
    "min_child_weight" : [1, 2, 3],
    "gamma"            : [0.0, 0.1, 0.2 , 0.3],
    "colsample_bytree" : [0.6, 0.8, 1]
}

# %%
test_results_df = pd.DataFrame()
for train_index, test_index in skf.split(df[list(set(df.columns) - {'label'})], df['label']):
    df_train = df.iloc[train_index]
    df_test = df.iloc[test_index]
    
    df_train, df_test = LOO_encoder(df_train, df_test, categorical_cols, 'label')
    df_train, df_test = OH_encoder(df_train, df_test, ordinal_cols)
    cols = ['id', 'label'] + list(set(df_train.columns) - \
                            {'bags_color', 'bags_condition', 'materials_list', 'size', 'label'} - remove_cols)
    
    cols = refine_cols(cols)
    
    df_train = df_train[cols]
    df_test = df_test[cols]

    sm = SMOTE(random_state=42)
    X, y = sm.fit_resample(df_train[cols[2:]], df_train['label'])
    
    #support vector machines
    for params in grid_search_params(svm_params):
        print(params)
        svm_clf = svm.SVC(probability=True, **params)
        svm_clf.fit(X, y)
        df_test['svm_pred_%s'%params] = svm_clf.predict(df_test[cols[2:]])
        df_test['svm_prob_%s'%params] = [item[1] for item in svm_clf.predict_proba(df_test[cols[2:]])]
        df_test['svm_prob_false_%s'%params] = [item[0] for item in svm_clf.predict_proba(df_test[cols[2:]])]
    
    # logistic regression
    for params in grid_search_params(lr_params):
        print(params)
        lr_clf = LogisticRegression(**params).fit(X, y)

        df_test['lr_pred_%s'%params] = lr_clf.predict(df_test[cols[2:]])
        df_test['lr_prob_%s'%params] = [item[1] for item in lr_clf.predict_proba(df_test[cols[2:]])]
        df_test['lr_prob_false_%s'%params] = [item[0] for item in lr_clf.predict_proba(df_test[cols[2:]])]
    
    #xgboost
    for params in grid_search_params(xgb_params):
        print(params)    
        xgb_clf = XGBClassifier(**params)
        xgb_clf.fit(X, y)
    
        df_test['xgb_pred_%s'%params] = xgb_clf.predict(df_test[cols[2:]])
        df_test['xgb_prob_%s'%params] = [item[1] for item in xgb_clf.predict_proba(df_test[cols[2:]])]
        df_test['xgb_prob_false_%s'%params] = [item[0] for item in xgb_clf.predict_proba(df_test[cols[2:]])]
        
    test_results_df = test_results_df.append(df_test)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 1}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 10}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 100}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 1}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 10}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 100}
# {'gamma': 1, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 1, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 1, 'kernel': 'rbf', 'C': 1}
# {'gamma': 1, 'kernel': 'rbf', 'C': 10}
# {'gamma': 1, 'kernel': 'rbf', 'C': 100}
# {'gamma': 10, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 10, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 10, 'kernel': 'rbf', 'C': 1}
# {'gamma': 10, 'kernel': 'rbf', 'C': 10}
# {'gamma': 10, 'kernel': 'rbf', 'C': 100}
# {'gamma': 100, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 100, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 100, 'kernel': 'rbf', 'C': 1}
# {'gamma': 100, 'kernel': 'rbf', 'C': 10}
# {'gamma': 100, 'kernel': 'rbf', 'C': 100}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 0.01}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 0.1}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 1}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 10}
# The line search algorithm did not converge
# The line search algorithm did not converge
# newton-cg failed to converge. Increase the number of iterations.
# newton-cg failed to converge. Increase the number of iterations.
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 100}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 0.01}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 0.1}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 1}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 10}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 100}
# {'solver': 'sag', 'penalty': 'l2', 'C': 0.01}
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# {'solver': 'sag', 'penalty': 'l2', 'C': 0.1}
# {'solver': 'sag', 'penalty': 'l2', 'C': 1}
# {'solver': 'sag', 'penalty': 'l2', 'C': 10}
# {'solver': 'sag', 'penalty': 'l2', 'C': 100}
# {'solver': 'saga', 'penalty': 'l2', 'C': 0.01}
# {'solver': 'saga', 'penalty': 'l2', 'C': 0.1}
# {'solver': 'saga', 'penalty': 'l2', 'C': 1}
# {'solver': 'saga', 'penalty': 'l2', 'C': 10}
# {'solver': 'saga', 'penalty': 'l2', 'C': 100}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 1}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 10}
# {'gamma': 0.01, 'kernel': 'rbf', 'C': 100}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 1}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 10}
# {'gamma': 0.1, 'kernel': 'rbf', 'C': 100}
# {'gamma': 1, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 1, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 1, 'kernel': 'rbf', 'C': 1}
# {'gamma': 1, 'kernel': 'rbf', 'C': 10}
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# {'gamma': 1, 'kernel': 'rbf', 'C': 100}
# {'gamma': 10, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 10, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 10, 'kernel': 'rbf', 'C': 1}
# {'gamma': 10, 'kernel': 'rbf', 'C': 10}
# {'gamma': 10, 'kernel': 'rbf', 'C': 100}
# {'gamma': 100, 'kernel': 'rbf', 'C': 0.01}
# {'gamma': 100, 'kernel': 'rbf', 'C': 0.1}
# {'gamma': 100, 'kernel': 'rbf', 'C': 1}
# {'gamma': 100, 'kernel': 'rbf', 'C': 10}
# {'gamma': 100, 'kernel': 'rbf', 'C': 100}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 0.01}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 0.1}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 1}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 10}
# {'solver': 'newton-cg', 'penalty': 'l2', 'C': 100}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 0.01}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 0.1}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 1}
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# The max_iter was reached which means the coef_ did not converge
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 10}
# {'solver': 'lbfgs', 'penalty': 'l2', 'C': 100}
# {'solver': 'sag', 'penalty': 'l2', 'C': 0.01}
# {'solver': 'sag', 'penalty': 'l2', 'C': 0.1}
# {'solver': 'sag', 'penalty': 'l2', 'C': 1}
# {'solver': 'sag', 'penalty': 'l2', 'C': 10}
# {'solver': 'sag', 'penalty': 'l2', 'C': 100}
# {'solver': 'saga', 'penalty': 'l2', 'C': 0.01}
# {'solver': 'saga', 'penalty': 'l2', 'C': 0.1}
# {'solver': 'saga', 'penalty': 'l2', 'C': 1}
# {'solver': 'saga', 'penalty': 'l2', 'C': 10}
# {'solver': 'saga', 'penalty': 'l2', 'C': 100}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# ...
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.6, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 0.8, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.1, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.2, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 1, 'max_depth': 8, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.3}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.2}
# {'colsample_bytree': 1, 'gamma': 0.3, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.3}

# %%
def model_result_stats(df_test, method_col):

    t1 = df_test[df_test.apply(lambda x: x['label'] == 1 and x[method_col] == 1, axis = 1)].shape[0]
    f0 = df_test[df_test.apply(lambda x: x['label'] == 1 and x[method_col] == 0, axis = 1)].shape[0]
    f1 = df_test[df_test.apply(lambda x: x['label'] == 0 and x[method_col] == 1, axis = 1)].shape[0]
    t0 = df_test[df_test.apply(lambda x: x['label'] == 0 and x[method_col] == 0, axis = 1)].shape[0]
    
    model_stats = 0
    if t1 + f1 > 0:
        model_stats += (t1 / (t1 + f1))
    if t0 + f0 > 0:
        model_stats += (t0 / (t0 + f0))
    if t1 + f0 > 0:
        model_stats += (t1 / (t1 + f0))
    if t0 + f1 > 0:
        model_stats += (t0 / (t0 + f1))
    
    return model_stats

# %%
def choose_best_model(df, re:str):
    cols = [col for col in df.columns if col.startswith(re)]
    best_method = None
    best_metric = inf
    for col in cols:
        col_metric = model_result_stats(df, col)
        if col_metric < best_metric:
            best_metric = col_metric
            best_method = col
    return best_method, best_metric

# %%
best_svm, best_svm_metric = choose_best_model(test_results_df, 'svm_pred_')
best_lr, best_lr_metric = choose_best_model(test_results_df, 'lr_pred_')
best_xgb, best_xgb_metric = choose_best_model(test_results_df, 'xgb_pred_')

best_svm_spec = best_svm[len('svm_pred_'):]
best_lr_spec = best_lr[len('lr_pred_'):]
best_xgb_spec = best_xgb[len('xgb_pred_'):]

# %%
best_xgb
# Out:
# "xgb_pred_{'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}"

# %%
test_results_df['ensemble_prob'] = test_results_df.apply(lambda x: (x['svm_prob_'+best_svm_spec] +
                                                    x['lr_prob_'+best_lr_spec] +
                                                    x['xgb_prob_'+best_xgb_spec]) / 3, axis = 1)
test_results_df['ensemble_pred'] = test_results_df['ensemble_prob'].apply(lambda x: 0 if x <= 0.5 else 1)
test_results_df['ensemble_prob_false'] = test_results_df['ensemble_prob'].apply(lambda x: 1-x)

# %%
def model_result_stats_expanded(model_stats, df_test, method_col):
    print(method_col)
    t1 = df_test[df_test.apply(lambda x: x['label'] == 1 and x[method_col] == 1, axis = 1)].shape[0]
    f0 = df_test[df_test.apply(lambda x: x['label'] == 1 and x[method_col] == 0, axis = 1)].shape[0]
    f1 = df_test[df_test.apply(lambda x: x['label'] == 0 and x[method_col] == 1, axis = 1)].shape[0]
    t0 = df_test[df_test.apply(lambda x: x['label'] == 0 and x[method_col] == 0, axis = 1)].shape[0]
    
    print(t1, f0, f1, t0)
    model_stats[method_name] = [0]
    if t1 + f1 > 0:
        model_stats[method_name][0] += (t1 / (t1 + f1))
    if t0 + f0 > 0:
        model_stats[method_name][0] += (t0 / (t0 + f0))
    if t1 + f0 > 0:
        model_stats[method_name][0] += (t1 / (t1 + f0))
    if t0 + f1 > 0:
        model_stats[method_name][0] += (t0 / (t0 + f1))

    print(t1/(t1+f1))
    print(t0/(t0+f0))
    print(t1/(t1+f0))
    print(t0/(t0+f1))
    model_stats[method_name].append(t1/(t1+f1))
    model_stats[method_name].append(t0/(t0+f0))
    
    return model_stats

# %%
test_results_df.shape
# Out:
# (33, 801)

# %%
model_stats = {}

model_stats = model_result_stats_expanded(model_stats, test_results_df, best_svm, best_svm)
model_stats = model_result_stats_expanded(model_stats, test_results_df, best_lr, best_lr)
model_stats = model_result_stats_expanded(model_stats, test_results_df, best_xgb, best_xgb)
model_stats = model_result_stats_expanded(model_stats, test_results_df, 'ensemble_pred', 'ensemble')
# Out:
# svm_pred_{'gamma': 0.1, 'kernel': 'rbf', 'C': 1}
# 11 5 9 8
# 0.55
# 0.6153846153846154
# 0.6875
# 0.47058823529411764
# lr_pred_{'solver': 'lbfgs', 'penalty': 'l2', 'C': 1}
# 6 10 10 7
# 0.375
# 0.4117647058823529
# 0.375
# 0.4117647058823529
# xgb_pred_{'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
# 12 4 3 14
# 0.8
# 0.7777777777777778
# 0.75
# 0.8235294117647058
# ensemble
# 10 6 7 10
# 0.5882352941176471
# 0.625
# 0.625
# 0.5882352941176471

# %%
best_method = [method for method in model_stats.keys() if
 model_stats[method][0] == max([model_stats[method][0] for method in model_stats.keys()])][0]
best_precision_1 = model_stats[best_method][1]
best_precision_0 = model_stats[best_method][2]

# %%
best_method
# Out:
# "xgb_pred_{'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}"

# %%
df_train, df_test = LOO_encoder(df_copy_train, df_copy_test, categorical_cols, 'label')
df_train, df_test = OH_encoder(df_copy_train, df_copy_test, ordinal_cols)

encoded_df = df_train[:]
cols = ['label'] + list(set(df_train.columns) - \
                        {'bags_color', 'bags_condition', 'materials_list', 'size', 'label'} - remove_cols)
cols = refine_cols(cols)
    
df_train = df_train[cols]

X, y = df_train[cols[1:]], df_train['label']

if best_method.startswith('svm'):
    params = eval(best_svm_spec)
    clf = svm.SVC(probability=True, **params).fit(X, y)
elif best_method.startswith('lr'):
    params = eval(best_lr_spec)
    clf = LogisticRegression(**params).fit(X, y)
elif best_method.startswith('xgb'):
    params = eval(best_xgb_spec)
    clf = XGBClassifier(**params).fit(X, y)
xgb_clf = clf

# %%
with open('lifetime_models_spec.pkl', 'rb') as file:
    models_dict = pickle.load(file)
models_dict[brand] = {'name': best_method, 'model': clf, 'df_train': df_train, 'df_test': df_test, 'features':cols[1:],
                      'precision_class1': best_precision_1, 'precision_class0': best_precision_0,
                      'test_reults_df': test_results_df, 'encoded_df': encoded_df}
with open('lifetime_models_spec.pkl', 'wb') as file:
    pickle.dump(models_dict,file)

# %%
plt.figure(figsize=(10,10))
sns.set(font_scale=1)
sns.heatmap(df_train[cols].corr(), annot = True, square=True, fmt='.2f', vmin=-1, vmax=1, center= 0, cmap= 'Greys')

# %% [markdown]
# # ROC curves

# %%
import warnings
warnings.filterwarnings("ignore")

# load libraries
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# Get predicted probabilities
y_score1 = test_results_df['svm_prob_false_'+best_svm_spec]
y_score2 = test_results_df['lr_prob_false_'+best_lr_spec]
y_score3 = test_results_df['xgb_prob_false_'+best_xgb_spec]
y_score4 = test_results_df['ensemble_prob_false']

# Plot Receiving Operating Characteristic Curve
# Create true and false positive rates
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(test_results_df['label'], y_score1)
false_positive_rate2, true_positive_rate2, threshold2 = roc_curve(test_results_df['label'], y_score2)
false_positive_rate3, true_positive_rate3, threshold3 = roc_curve(test_results_df['label'], y_score3)
false_positive_rate4, true_positive_rate4, threshold4 = roc_curve(test_results_df['label'], y_score4)
print('roc_auc_score for DecisionTree: ', roc_auc_score(test_results_df['label'], y_score1))
print('roc_auc_score for Logistic Regression: ', roc_auc_score(test_results_df['label'], y_score2))
print('roc_auc_score for XGBoost: ', roc_auc_score(test_results_df['label'], y_score3))
print('roc_auc_score for Ensemble: ', roc_auc_score(test_results_df['label'], y_score4))
# Out:
# roc_auc_score for DecisionTree:  0.5533088235294117
# roc_auc_score for Logistic Regression:  0.6470588235294118
# roc_auc_score for XGBoost:  0.10661764705882355
# roc_auc_score for Ensemble:  0.3529411764705882

# %%
plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Support Vector Machines')
plt.plot(true_positive_rate1, false_positive_rate1, color='Black')
plt.plot([0, 1], ls="--", color='Grey')
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
plt.subplots(1, figsize=(5,5))
plt.plot(true_positive_rate2, false_positive_rate2, color='Black')
plt.plot([0, 1], ls="--", color='Grey')
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Extreme Gradient Boosting')
plt.plot(true_positive_rate3, false_positive_rate3, color='Black')
plt.plot([0, 1], ls="--", color='Grey')
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Ensemble Model')
plt.plot(true_positive_rate4, false_positive_rate4, color='Black')
plt.plot([0, 1], ls="--", color='Grey')
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # Shap

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
explainer = shap.TreeExplainer(xgb_clf)

# %%
shap_values = explainer.shap_values(X.as_matrix())

# %%
shap.summary_plot(shap_values, X)

# %%
shap.summary_plot(shap_values, X, plot_type="bar")

# %%
shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# <div id='iAGS14S2G9W9C6145TKAN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["model output value"], "baseValue": -0.08913098275661469, "outValue": 2.335984230041504, "link": "identity", "featureNames": ["retail_price_refined", "materials_list_loo", "bags_color_loo", "original_to_avg", "size_loo", "bags_price_refined", "bags_condition_Like new", "search_fendi", "price_to_retail", "number_similar", "search_fendi_kan_i", "bags_condition_Gently used", "search_tradesy_fendi"], "features": {"0": {"effect": -0.1140255481004715, "value": 1750.0}, "1": {"effect": 0.3137185573577881, "value": 0.5555555555555556}, "2": {"effect": -0.4894513487815857, "value": 0.0}, "4": {"effect": 2.084744453430176, "value": 0.5}, "5": {"effect": 0.09123668074607849, "value": 1232.0}, "7": {"effect": -0.05066709220409393, "value": 55.0}, "10": {"effect": 0.5895593762397766, "value": 20.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iAGS14S2G9W9C6145TKAN')
#   );
# </script>

# %%
shap.force_plot(explainer.expected_value, shap_values, X)
# Out:
# <div id='iML3TTZ5G63WI3NZWEDSF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["model output value"], "baseValue": -0.08913098275661469, "link": "identity", "featureNames": ["retail_price_refined", "materials_list_loo", "bags_color_loo", "original_to_avg", "size_loo", "bags_price_refined", "bags_condition_Like new", "search_fendi", "price_to_retail", "number_similar", "search_fendi_kan_i", "bags_condition_Gently used", "search_tradesy_fendi"], "explanations": [{"outValue": 2.335984230041504, "simIndex": 2.0, "features": {"0": {"effect": -0.1140255481004715, "value": 1750.0}, "1": {"effect": 0.3137185573577881, "value": 0.5555555555555556}, "2": {"effect": -0.4894513487815857, "value": 0.0}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": 2.084744453430176, "value": 0.5}, "5": {"effect": 0.09123668074607849, "value": 1232.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": -0.05066709220409393, "value": 55.0}, "8": {"effect": 0.0, "value": 0.704}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.5895593762397766, "value": 20.0}, "11": {"effect": 0.0, "value": 1.0}, "12": {"effect": 0.0, "value": -2.0}}}, {"outValue": -1.5059481859207153, "simIndex": 30.0, "features": {"0": {"effect": 0.0704350620508194, "value": 2950.0}, "1": {"effect": -0.1980934739112854, "value": 0.5}, "2": {"effect": -0.6872135400772095, "value": 0.5}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": -1.2320741415023804, "value": 0.45454545454545453}, "5": {"effect": 0.09123668074607849, "value": 1715.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": -0.05066709220409393, "value": 55.0}, "8": {"effect": 0.0, "value": 0.5813559322033899}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.5895593762397766, "value": 20.0}, "11": {"effect": 0.0, "value": 1.0}, "12": {"effect": 0.0, "value": -2.0}}}, {"outValue": 2.117091178894043, "simIndex": 12.0, "features": {"0": {"effect": 0.0704350620508194, "value": 2450.0}, "1": {"effect": -0.1980934739112854, "value": 0.36363636363636365}, "2": {"effect": 0.6816599369049072, "value": 1.0}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": 2.084744453430176, "value": 0.5}, "5": {"effect": 0.09123668074607849, "value": 1795.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": -0.05066709220409393, "value": 58.0}, "8": {"effect": 0.0, "value": 0.7326530612244898}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": -0.4730936288833618, "value": 59.0}, "11": {"effect": 0.0, "value": 0.0}, "12": {"effect": 0.0, "value": 0.0}}}, {"outValue": 2.496234893798828, "simIndex": 3.0, "features": {"0": {"effect": 0.0704350620508194, "value": 2600.0}, "1": {"effect": 0.3137185573577881, "value": 0.5555555555555556}, "2": {"effect": -0.523676335811615, "value": 0.46875}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": 2.084744453430176, "value": 0.5}, "5": {"effect": 0.09123668074607849, "value": 1770.0}, "6": {"effect": 0.0, "value": 1.0}, "7": {"effect": 0.07361607253551483, "value": 49.0}, "8": {"effect": 0.0, "value": 0.6807692307692308}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.47529137134552, "value": 24.0}, "11": {"effect": 0.0, "value": 0.0}, "12": {"effect": 0.0, "value": 1.0}}}, {"outValue": 1.5202224254608154, "simIndex": 7.0, "features": {"0": {"effect": 0.0704350620508194, "value": 2890.0}, "1": {"effect": 0.3137185573577881, "value": 0.5555555555555556}, "2": {"effect": 0.6816599369049072, "value": 1.0}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": 1.0605157613754272, "value": 0.36363636363636365}, "5": {"effect": -0.11749844998121262, "value": 2605.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": 0.07361607253551483, "value": 51.0}, "8": {"effect": 0.0, "value": 0.9013840830449827}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": -0.4730936288833618, "value": 44.0}, "11": {"effect": 0.0, "value": 0.0}, "12": {"effect": 0.0, "value": -2.0}}}, {"outValue": -1.1585420370101929, "simIndex": 18.0, "features": {"0": {"effect": -0.1140255481004715, "value": 2 ...

# %%
print(best_method)
# Out:
# xgb_pred_{'colsample_bytree': 0.6, 'gamma': 0.0, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.2}
